# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

# Paste your API key from https://makersuite.google.com/app/apikey
API_KEY = "AIzaSyBox_qU8zp6T0jp7SLVpz6xJuK18dNJvQo"

genai.configure(api_key=API_KEY)

# %%
def generate_gemini_prompt(code: str, lang: str = "Python") -> str:
    return f"""
You are a helpful AI assistant. Refactor the following {lang} code:

### GOALS:
- Improve naming (variables/functions)
- Split large functions if needed
- Optimize performance (loops, logic)
- Follow clean code practices

### ORIGINAL CODE ({lang}):
{code}

### REFACTORED CODE ({lang}):
"""

# %%
def refactor_with_gemini(code: str, lang: str = "Python"):
    prompt = generate_gemini_prompt(code, lang)

    model = genai.GenerativeModel("gemini-pro")  # or use "gemini-pro"
    response = model.generate_content(prompt)

    return response.text.strip()

# %%
messy_code = """
def a(x):
 for i in range(len(x)):
  for j in range(len(x[i])):
   if x[i][j]%2==0:x[i][j]=x[i][j]*2
   else:x[i][j]=x[i][j]+1
 return x
"""

refactored = refactor_with_gemini(messy_code)
print("🔧 Refactored Code:\n")
print(refactored)
# Out:
# WARNING:tornado.access:404 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 2857.29ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# /tmp/ipython-input-2490487809.py in <cell line: 0>()
#       8 """
#       9
# ---> 10 refactored = refactor_with_gemini(messy_code)
#      11 print("🔧 Refactored Code:\n")
#      12 print(refactored)
#
# /tmp/ipython-input-3224918158.py in refactor_with_gemini(code, lang)
#       3
#       4     model = genai.GenerativeModel("gemini-pro")  # or use "gemini-pro"
# ----> 5     response = model.generate_content(prompt)
#       6
#       7     return response.text.strip()
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
# ...
